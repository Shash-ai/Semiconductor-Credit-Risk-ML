# %%
import pandas as pd
import os

print(os.getcwd())
# Out:
# /Users/shashankyadav/Library/CloudStorage/OneDrive-WOXSENUNIVERSITY/Semiconductor_Credit_Risk_ML/03_Notebooks
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
iip_path = "../01_Raw_Data/Industrial_Production/IIP_Dashboard Data_Jun2026-28.07.2026.xlsx"

xls = pd.ExcelFile(iip_path)

print(xls.sheet_names)
# Out:
# ['UBC-Monthly', 'Sectoral-Monthly', 'UBC-Annual', 'Sectoral-Annual', 'Sectoral Weights']

# %%
import os

print(os.listdir("../01_Raw_Data/Industrial_Production"))
# Out:
# ['.DS_Store', 'IIP_Dashboard Data_Jun2026-28.07.2026.xlsx']

# %%
iip = pd.read_excel(
    iip_path,
    sheet_name=0,
    header=None
)

print("Shape:", iip.shape)
display(iip.head(15))
# Out:
# Shape: (7, 41)
#                                    0       1                    2   \
# 0                  Use-based category  Weight  2023-04-01 00:00:00
# 1                       Primary goods  31.136                  1.3
# 2                       Capital goods   8.082                 -4.7
# 3                  Intermediate goods  22.416                  0.6
# 4  Infrastructure/ construction goods  10.908                  5.7
# 5                   Consumer durables  11.311                   -4
# 6               Consumer non-durables  16.147                  0.6
#
#                     3                    4                    5   \
# 0  2023-05-01 00:00:00  2023-06-01 00:00:00  2023-07-01 00:00:00
# 1                  5.8                  5.4                 -0.9
# 2                  1.6                  8.8                  4.1
# 3                  5.5                  1.7                  4.8
# 4                  7.9                  7.4                  7.3
# ...

# %%
display(iip.tail(10))
# Out:
#                                    0       1                    2   \
# 0                  Use-based category  Weight  2023-04-01 00:00:00
# 1                       Primary goods  31.136                  1.3
# 2                       Capital goods   8.082                 -4.7
# 3                  Intermediate goods  22.416                  0.6
# 4  Infrastructure/ construction goods  10.908                  5.7
# 5                   Consumer durables  11.311                   -4
# 6               Consumer non-durables  16.147                  0.6
#
#                     3                    4                    5   \
# 0  2023-05-01 00:00:00  2023-06-01 00:00:00  2023-07-01 00:00:00
# 1                  5.8                  5.4                 -0.9
# 2                  1.6                  8.8                  4.1
# 3                  5.5                  1.7                  4.8
# 4                  7.9                  7.4                  7.3
# ...

# %%
print(iip.dtypes)
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# 15    object
# 16    object
# 17    object
# 18    object
# 19    object
# 20    object
# 21    object
# 22    object
# 23    object
# 24    object
# 25    object
# 26    object
# 27    object
# 28    object
# 29    object
# 30    object
# 31    object
# 32    object
# 33    object
# 34    object
# 35    object
# 36    object
# 37    object
# 38    object
# 39    object
# 40    object
# dtype: object

# %%
import os

print(os.listdir("../01_Raw_Data/Industrial_Production"))
# Out:
# ['.DS_Store', 'IIP_Dashboard Data_Jun2026-28.07.2026.xlsx']

# %%
import pandas as pd
import os

iip_path = "../01_Raw_Data/Industrial_Production/IIP_Dashboard Data_Jun2026-28.07.2026.xlsx"

xls = pd.ExcelFile(iip_path)

print("Sheets available:")
print(xls.sheet_names)
# Out:
# Sheets available:
# ['UBC-Monthly', 'Sectoral-Monthly', 'UBC-Annual', 'Sectoral-Annual', 'Sectoral Weights']

# %%
for sheet in xls.sheet_names:
    temp = pd.read_excel(iip_path, sheet_name=sheet, header=None)
    
    print("\n" + "="*60)
    print("SHEET:", sheet)
    print("SHAPE:", temp.shape)
    print("="*60)
    
    display(temp.head(10))
# Out:
# ...
# SHEET: UBC-Monthly
# SHAPE: (7, 41)
# ...
#                                    0       1                    2   \
# 0                  Use-based category  Weight  2023-04-01 00:00:00
# 1                       Primary goods  31.136                  1.3
# 2                       Capital goods   8.082                 -4.7
# 3                  Intermediate goods  22.416                  0.6
# 4  Infrastructure/ construction goods  10.908                  5.7
# 5                   Consumer durables  11.311                   -4
# 6               Consumer non-durables  16.147                  0.6
#
#                     3                    4                    5   \
# 0  2023-05-01 00:00:00  2023-06-01 00:00:00  2023-07-01 00:00:00
# 1                  5.8                  5.4                 -0.9
# 2                  1.6                  8.8                  4.1
# 3                  5.5                  1.7                  4.8
# 4                  7.9                  7.4                  7.3
# ...

# %%
import os

iip_clean_dir = "../02_Clean_Data/IIP"

os.makedirs(iip_clean_dir, exist_ok=True)

print("Created:", iip_clean_dir)
# Out:
# Created: ../02_Clean_Data/IIP

# %%
weights = pd.read_excel(
    iip_path,
    sheet_name="Sectoral Weights"
)

display(weights)
# Out:
#                                      NIC 2025  \
# 0                                       05-06
# 1                                          07
# 2                                          08
# 3                          Mining & Quarrying
# 4                                          10
# 5                                          11
# 6                                          12
# 7                                          13
# 8                                          14
# 9                                          15
# 10                                         16
# 11                                         17
# 12                                         18
# 13                                         19
# 14                                         20
# 15                                         21
# 16                                         22
# 17                                         23
# 18                                         24
# ...

# %%
sectoral = pd.read_excel(
    iip_path,
    sheet_name="Sectoral-Monthly"
)

print(sectoral.columns.tolist())
print(sectoral.shape)
# Out:
# ['Description', 'Weights', datetime.datetime(2023, 4, 1, 0, 0), datetime.datetime(2023, 5, 1, 0, 0), datetime.datetime(2023, 6, 1, 0, 0), datetime.datetime(2023, 7, 1, 0, 0), datetime.datetime(2023, 8, 1, 0, 0), datetime.datetime(2023, 9, 1, 0, 0), datetime.datetime(2023, 10, 1, 0, 0), datetime.datetime(2023, 11, 1, 0, 0), datetime.datetime(2023, 12, 1, 0, 0), datetime.datetime(2024, 1, 1, 0, 0), datetime.datetime(2024, 2, 1, 0, 0), datetime.datetime(2024, 3, 1, 0, 0), datetime.datetime(2024, 4, 1, 0, 0), datetime.datetime(2024, 5, 1, 0, 0), datetime.datetime(2024, 6, 1, 0, 0), datetime.datetime(2024, 7, 1, 0, 0), datetime.datetime(2024, 8, 1, 0, 0), nan, 'nan.1', 'nan.2', datetime.datetime(2024, 12, 1, 0, 0), datetime.datetime(2025, 1, 1, 0, 0), datetime.datetime(2025, 2, 1, 0, 0), datetime.datetime(2025, 3, 1, 0, 0), datetime.datetime(2025, 4, 1, 0, 0), datetime.datetime(2025, 5, 1, 0, 0), datetime.datetime(2025, 6, 1, 0, 0), datetime.datetime(2025, 7, 1, 0, 0), datetime.datetime(2
# ...

# %%
sectoral = pd.read_excel(
    iip_path,
    sheet_name="Sectoral-Monthly"
)

display(
    sectoral.iloc[:, 15:25]
)
# Out:
#    2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00  \
# 0                  7.6                  4.7                  4.0
# 1                  6.0                  7.2                  7.8
# 2                 13.9                  9.4                  9.0
# 3                 14.2                 12.5                 13.1
# 4                  7.3                  7.3                  7.8
#
#    2024-08-01 00:00:00   NaN  nan.1  nan.2  2024-12-01 00:00:00  \
# 0                 -5.0   0.4    1.4    3.9                  3.9
# 1                  3.4   5.5    6.4    6.2                  6.4
# 2                 -3.4   0.7    3.0    4.5                  6.1
# 3                 12.2  11.4   12.3   11.8                 11.6
# 4                  2.1   4.7    5.6    5.9                  6.1
#
#    2025-01-01 00:00:00  2025-02-01 00:00:00
# 0                  3.3                  0.5
# 1                  7.2                  3.1
# 2                  1.6                  3.0
# ...

# %%
print(xls.sheet_names)
# Out:
# ['UBC-Monthly', 'Sectoral-Monthly', 'UBC-Annual', 'Sectoral-Annual', 'Sectoral Weights']

# %%
iloc[:, 15:25]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 iloc[:, 15:25]
#
# NameError: name 'iloc' is not defined

# %%
sectoral = pd.read_excel(
    iip_path,
    sheet_name="Sectoral-Monthly"
)

display(sectoral.iloc[:, 15:25])
# Out:
#    2024-05-01 00:00:00  2024-06-01 00:00:00  2024-07-01 00:00:00  \
# 0                  7.6                  4.7                  4.0
# 1                  6.0                  7.2                  7.8
# 2                 13.9                  9.4                  9.0
# 3                 14.2                 12.5                 13.1
# 4                  7.3                  7.3                  7.8
#
#    2024-08-01 00:00:00   NaN  nan.1  nan.2  2024-12-01 00:00:00  \
# 0                 -5.0   0.4    1.4    3.9                  3.9
# 1                  3.4   5.5    6.4    6.2                  6.4
# 2                 -3.4   0.7    3.0    4.5                  6.1
# 3                 12.2  11.4   12.3   11.8                 11.6
# 4                  2.1   4.7    5.6    5.9                  6.1
#
#    2025-01-01 00:00:00  2025-02-01 00:00:00
# 0                  3.3                  0.5
# 1                  7.2                  3.1
# 2                  1.6                  3.0
# ...

# %%
os.listdir("../01_Raw_Data/Interest_Rates")
# Out:
# ['Weighted Average Lending Rate.xlsx',
#  'Major Monetary Policy Rates and Reserve Requirements - Bank Rate, LAF (Repo, Reverse Repo, SDF and MSF) Rates, CRR & SLR.xlsx',
#  'Other STRBI Table No 18. Bank Group-Wise and Occupation-Wise Weighted Average Lending Rate and Deposit Rate.xlsx']
